# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)
pd.set_option('display.max_columns', None)

# %%
def time_parser(x):
    return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams.update({'font.size': 12})

colors = ["#9b59b6", "#e74c3c", "#34495e", "#2ecc71",'#415952', '#f35134', '#243AB5', '#243AB5', '#243AB5']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_active_energy_kW']#'Consumed_apparent_energy_kVAh',]
data = pd.read_csv('../power_test.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data1 = data[data['dev_name']=='ADB1_CRAC3']
target1 = data1['Consumed_active_energy_kW']
data1 = data1.reset_index()
print(target1.tail())
data2 =  data[data['dev_name']=='ADB1_CRAC4']
data2 = data2.reset_index()

target2 =  data2['Consumed_active_energy_kW']

#fig,ax = plt.subplots()

#fig  = plt.figure(figsize=(14,12))


ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[0],label=['CRAC3'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[1],label=['CRAC4']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed active energy kW")
plt.ylim(0,28000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.savefig('CRAC3_CRAC4_power_out.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Timestamp
# 2018-07-10 10:18:00    21275.0
# 2018-07-10 10:18:46    21275.0
# 2018-07-10 10:19:32    21276.0
# 2018-07-10 10:20:17    21276.0
# 2018-07-10 10:21:03    21276.0
# Name: Consumed_active_energy_kW, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_apparent_energy_kVAh',]
data = pd.read_csv('../power_test.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data1 = data[data['dev_name']=='ADB1_CRAC3']
target1 = data1['Consumed_active_energy_kW']
data1 = data1.reset_index()
print(target1.tail())
data2 =  data[data['dev_name']=='ADB1_CRAC4']
data2 = data2.reset_index()

target2 =  data2['Consumed_active_energy_kW']

#fig,ax = plt.subplots()

#fig  = plt.figure(figsize=(14,12))


ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[0],label=['CRAC3'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[1],label=['CRAC4']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed apparent energy kW")
plt.ylim(0,28000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.savefig('CRAC3_CRAC4_apparent_power_out.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Timestamp
# 2018-07-10 10:18:00    21275.0
# 2018-07-10 10:18:46    21275.0
# 2018-07-10 10:19:32    21276.0
# 2018-07-10 10:20:17    21276.0
# 2018-07-10 10:21:03    21276.0
# Name: Consumed_active_energy_kW, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_capacitive_reactive_energy_varhC',]
data = pd.read_csv('../power_test.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data1 = data[data['dev_name']=='ADB1_CRAC3']
target1 = data1['Consumed_active_energy_kW']
data1 = data1.reset_index()
print(target1.tail())
data2 =  data[data['dev_name']=='ADB1_CRAC4']
data2 = data2.reset_index()

target2 =  data2['Consumed_active_energy_kW']

#fig,ax = plt.subplots()

#fig  = plt.figure(figsize=(14,12))


ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[0],label=['CRAC3'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[1],label=['CRAC4']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed capacitive_reactive_energy_varhC")
plt.ylim(0,28000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.savefig('CRAC3_CRAC4_capacitive_power_out.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Timestamp
# 2018-07-10 10:18:00    21275.0
# 2018-07-10 10:18:46    21275.0
# 2018-07-10 10:19:32    21276.0
# 2018-07-10 10:20:17    21276.0
# 2018-07-10 10:21:03    21276.0
# Name: Consumed_active_energy_kW, dtype: float64

# %%
data2.tail()
# Out:
#                 Timestamp    dev_name  Threephase_Power_Factor  \
# 98356 2018-07-10 10:18:00  ADB1_CRAC4                     0.37
# 98357 2018-07-10 10:18:46  ADB1_CRAC4                     0.75
# 98358 2018-07-10 10:19:32  ADB1_CRAC4                     0.37
# 98359 2018-07-10 10:20:17  ADB1_CRAC4                     0.37
# 98360 2018-07-10 10:21:03  ADB1_CRAC4                     0.50
#
#        Consumed_apparent_energy_VAh  L2_Current  L1_Active_Power  \
# 98356                         902.0        0.40             0.12
# 98357                         905.0        0.00             0.12
# 98358                         908.0        0.44             0.16
# 98359                         911.0        0.00             0.12
# 98360                         914.0        0.00             0.16
#
#        Consumed_capacitive_reactive_energy_kvarhC  L2_voltage__THD  \
# 98356                                         3.0             0.12
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_active_energy_kW']#'Consumed_apparent_energy_kVAh',]
data = pd.read_csv('../power_test.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data1 = data[data['dev_name']=='ADB1_CRAC3']
target1 = data1['Consumed_active_energy_kW']
data1 = data1.reset_index()
print(target1.tail())
data2 =  data[data['dev_name']=='ADB1_CRAC4']
data2 = data2.reset_index()

target2 =  data2['Consumed_active_energy_kW']

#fig,ax = plt.subplots()

#fig  = plt.figure(figsize=(14,12))


ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[0],label=['CRAC3'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[1],label=['CRAC4']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed active energy kW")
plt.ylim(0,28000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.savefig('CRAC3_CRAC4_power_out.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Timestamp
# 2018-07-10 10:18:00    21275.0
# 2018-07-10 10:18:46    21275.0
# 2018-07-10 10:19:32    21276.0
# 2018-07-10 10:20:17    21276.0
# 2018-07-10 10:21:03    21276.0
# Name: Consumed_active_energy_kW, dtype: float64

# %%
data.columns[47]
# Out:
# 'Consumed_capacitive_reactive_energy_varhC'

# %%
data.columns[56]
# Out:
# 'Consumed_apparent_energy_kVAh'

# %%
data.head(100)
# Out:
#                        dev_name  Threephase_Power_Factor  \
# Timestamp
# 2018-05-16 14:41:02  UDB1_ULC_5                    -0.93
# 2018-05-16 14:41:16  UDB1_ULC_5                    -0.93
# 2018-05-16 14:41:16  UDB2_ULC_6                    -0.93
# 2018-05-16 14:41:16  ADB1_CRAC3                     1.00
# 2018-05-16 14:41:16  ADB1_CRAC4                     0.94
# ...                         ...                      ...
# 2018-05-16 14:52:48  ADB1_CRAC3                     1.00
# 2018-05-16 14:52:48  ADB1_CRAC4                     0.94
# 2018-05-16 14:53:50  UDB1_ULC_5                    -0.93
# 2018-05-16 14:53:50  UDB2_ULC_6                    -0.93
# 2018-05-16 14:53:50  ADB1_CRAC3                     1.00
#
#                      Consumed_apparent_energy_VAh  L2_Current  \
# Timestamp
# 2018-05-16 14:41:02                         964.0        7.56
# 2018-05-16 14:41:16                         993.0        7.52
# 2018-05-16 14:41:16                         693.0        7.96
# ...

# %%
data1.tail()
# Out:
#                 Timestamp    dev_name  Threephase_Power_Factor  \
# 98347 2018-07-10 10:18:00  ADB1_CRAC3                     0.95
# 98348 2018-07-10 10:18:46  ADB1_CRAC3                     0.98
# 98349 2018-07-10 10:19:32  ADB1_CRAC3                     0.97
# 98350 2018-07-10 10:20:17  ADB1_CRAC3                     0.97
# 98351 2018-07-10 10:21:03  ADB1_CRAC3                     0.97
#
#        Consumed_apparent_energy_VAh  L2_Current  L1_Active_Power  \
# 98347                         127.0       30.12             7.04
# 98348                         407.0       42.60             9.96
# 98349                         790.0       40.24             9.92
# 98350                         139.0       39.60             9.76
# 98351                         496.0       40.20             9.88
#
#        Consumed_capacitive_reactive_energy_kvarhC  L2_voltage__THD  \
# 98347                                        23.0             0.11
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_apparent_energy_kVAh',]
data = pd.read_csv('../power_test.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data1 = data[data['dev_name']=='UDB1_ULC_5']
target1 = data1['Consumed_active_energy_kW']
data1 = data1.reset_index()
print(target1.tail())
data2 =  data[data['dev_name']=='UDB2_ULC_6']
data2 = data2.reset_index()

target2 =  data2['Consumed_active_energy_kW']

#fig,ax = plt.subplots()

#fig  = plt.figure(figsize=(14,12))


ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[2],label=['ULC5'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[3],label=['ULC6']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed_apparent_energy_kVAh")
plt.ylim(0,13000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.savefig('ULC5_ULC6_apparent_power_out.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Timestamp
# 2018-07-10 10:17:59    12324.0
# 2018-07-10 10:18:46    12324.0
# 2018-07-10 10:19:31    12325.0
# 2018-07-10 10:20:17    12325.0
# 2018-07-10 10:21:02    12325.0
# Name: Consumed_active_energy_kW, dtype: float64

# %%
data2.head()
# Out:
#             Timestamp    dev_name  Threephase_Power_Factor  \
# 0 2018-05-16 14:41:16  UDB2_ULC_6                    -0.93
# 1 2018-05-16 14:41:46  UDB2_ULC_6                    -0.93
# 2 2018-05-16 14:42:16  UDB2_ULC_6                    -0.93
# 3 2018-05-16 14:42:46  UDB2_ULC_6                    -0.93
# 4 2018-05-16 14:43:16  UDB2_ULC_6                    -0.93
#
#    Consumed_apparent_energy_VAh  L2_Current  L1_Active_Power  \
# 0                         693.0        7.96             3.76
# 1                         761.0        7.96             3.76
# 2                         824.0        7.96             3.76
# 3                         889.0        7.96             3.76
# 4                         957.0        7.92             3.80
#
#    Consumed_capacitive_reactive_energy_kvarhC  L2_voltage__THD  \
# 0                                       933.0             0.08
# 1                                       933.0             0.08
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_active_energy_kW']
data = pd.read_csv('../power_test.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data1 = data[data['dev_name']=='UDB1_ULC_5']
target1 = data1['Consumed_active_energy_kW']
data1 = data1.reset_index()
print(target1.tail())
data2 =  data[data['dev_name']=='UDB2_ULC_6']
data2 = data2.reset_index()

target2 =  data2['Consumed_active_energy_kW']

#fig,ax = plt.subplots()

#fig  = plt.figure(figsize=(14,12))


ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[2],label=['ULC5'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[3],label=['ULC6']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed active energy kW")
plt.ylim(0,13000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.savefig('ULC5_ULC6_power_out.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Timestamp
# 2018-07-10 10:17:59    12324.0
# 2018-07-10 10:18:46    12324.0
# 2018-07-10 10:19:31    12325.0
# 2018-07-10 10:20:17    12325.0
# 2018-07-10 10:21:02    12325.0
# Name: Consumed_active_energy_kW, dtype: float64

# %%
import sys
import os
import csv

csv_file = '../power_test.csv'
key_name  = 'ADB1_CRAC3'
i = 0
j = 0

k = 0 
   
max_val = [30000,23000]

min_val = [0,0]
field_num = [49,57]#,48,57] #57 is apparent 
increase = [True,True]
outfile ='./powertest_CRAC3.out.csv'
prev_val = [-1 ] * len(field_num)
c1 = 0
c2 = 0
c3 = 0
with open(csv_file) as csv_file, open(outfile,'w') as out_csv:
        csv_reader = csv.reader(csv_file, delimiter=',')
        csv_writer = csv.writer(out_csv,delimiter=',')
        
        for row in csv_reader:
           if i == 0:
               csv_writer.writerow(row)
               i += 1   # skip the first header row
               header_row = row
               for y in field_num:
                   print ('check field %s\n'%row[y])
               continue
           i =  i + 1
           found = False
           
           for column in row:
               #print(column)
               if column==key_name:
                   found = True;
                   j = j +1
                   break

           if found:
                error = False
                y = 0
                for x in field_num:
                   if increase[y] and prev_val[y] != -1 and  prev_val[y] > float(row[x]):
                       #print ('...not incrasing %d %s at row %d'%(prev_val[y],row[x],i))
                       #print (row)
                       c2 = c2+1
                       error = True 
                   if max_val[y] and float(row[x]) > max_val[y]:
                       #print ('...greater than outliner data at row %d'%i)
                       #print (row[x])
                       c3 = c3+1
                       error = True 
                   if min_val[y] and float(row[x]) <= min_val[y]:
                       #print ('...less than  outliner data at row %d'%i)
                       c1 = c1+1
                       #print (row)
                       error = True 
                   if error:
                       break
                   y = y + 1
                
                if not error:
                   csv_writer.writerow(row)  
                   for cnt, x in enumerate(field_num): 
                       prev_val[cnt] = max(prev_val[cnt],float(row[x]))
                   
                   k = k +1
                
        print('Processed %d  lines  cleaned line %d (%d, %d, %d)'%(i,k,c1,c2,c3))
# Out:
# check field Consumed_active_energy_kW
#
# check field Consumed_apparent_energy_kVAh
#
# Processed 393108  lines  cleaned line 95866 (0, 2482, 4)

# %%
csv_file = '../power_test.csv'
key_name  = 'ADB1_CRAC4'
i = 0
j = 0

k = 0 
   
max_val = [30000,23000]

min_val = [0,0]
field_num = [49,57]#,48,57] #57 is apparent 
increase = [True,True]
outfile ='./powertest_CRAC4.out.csv'
prev_val = [-1 ] * len(field_num)
c1 = 0
c2 = 0
c3 = 0
with open(csv_file) as csv_file, open(outfile,'w') as out_csv:
        csv_reader = csv.reader(csv_file, delimiter=',')
        csv_writer = csv.writer(out_csv,delimiter=',')
        
        for row in csv_reader:
           if i == 0:
               csv_writer.writerow(row)
               i += 1   # skip the first header row
               header_row = row
               for y in field_num:
                   print ('check field %s\n'%row[y])
               continue
           i =  i + 1
           found = False
           
           for column in row:
               #print(column)
               if column==key_name:
                   found = True;
                   j = j +1
                   break

           if found:
                error = False
                y = 0
                for x in field_num:
                   if increase[y] and prev_val[y] != -1 and  prev_val[y] > float(row[x]):
                       #print ('...not incrasing %d %s at row %d'%(prev_val[y],row[x],i))
                       #print (row)
                       c2 = c2+1
                       error = True 
                   if max_val[y] and float(row[x]) > max_val[y]:
                       #print ('...greater than outliner data at row %d'%i)
                       #print (row[x])
                       c3 = c3+1
                       error = True 
                   if min_val[y] and float(row[x]) <= min_val[y]:
                       #print ('...less than  outliner data at row %d'%i)
                       c1 = c1+1
                       #print (row)
                       error = True 
                   if error:
                       break
                   y = y + 1
                
                if not error:
                   csv_writer.writerow(row)  
                   for cnt, x in enumerate(field_num): 
                       prev_val[cnt] = max(prev_val[cnt],float(row[x]))
                   
                   k = k +1
                
        print('Processed %d  lines  cleaned line %d (%d, %d, %d)'%(i,k,c1,c2,c3))
# Out:
# check field Consumed_active_energy_kW
#
# check field Consumed_apparent_energy_kVAh
#
# Processed 393108  lines  cleaned line 96262 (0, 2040, 59)

# %%
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_active_energy_kW']
 



data1 = pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data2 = pd.read_csv('powertest_CRAC4.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

target1 = data1['Consumed_active_energy_kW']
target2 = data2['Consumed_active_energy_kW']

data1 = data1.reset_index()
data2= data2.reset_index()
ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[0],label=['CRAC3'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[1],label=['CRAC4']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed active energy kW")
plt.ylim(0,28000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.title('After dropped error values ')
plt.savefig('CRAC3_CRAC4_power_out_drop.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_apparent_energy_kVAh']
 



data1 = pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data2 = pd.read_csv('powertest_CRAC4.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

target1 = data1['Consumed_apparent_energy_kVAh']
target2 = data2['Consumed_apparent_energy_kVAh']

data1 = data1.reset_index()
data2= data2.reset_index()
ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[0],label=['CRAC3'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[1],label=['CRAC4']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed_apparent_energy_kVAh")
plt.ylim(0,28000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.title('After dropped error values ')
plt.savefig('CRAC3_CRAC4_apparent_power_out_drop.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_active_energy_kW']
 



data1 = pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data2 = pd.read_csv('powertest_CRAC4.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

target1 = data1['Consumed_active_energy_kW']
target2 = data2['Consumed_active_energy_kW']

data1 = data1.reset_index()
data2= data2.reset_index()
ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[0],label=['CRAC3'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[1],label=['CRAC4']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed_apparent_energy_kVAh")
plt.ylim(0,28000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.title('After dropped error values ')
plt.savefig('CRAC3_CRAC4_power_out_drop.csv'+'.png')
plt.show()

# %%
data1.head()

# %%
import sys
import os
import csv

csv_file = '../power_test.csv'
key_name  = 'UDB1_ULC_5'
outfile ='./powertest_ULC5.out.csv'

i = 0
j = 0
prev_val = -1 
k = 0 
   
max_val = [30000,23000]

min_val = [0,0]
field_num = [49,57]#,48,57] #57 is apparent 
increase = [True,True]

prev_val = [-1 ] * len(field_num)
c1 = 0
c2 = 0
c3 = 0
with open(csv_file) as csv_file, open(outfile,'w') as out_csv:
        csv_reader = csv.reader(csv_file, delimiter=',')
        csv_writer = csv.writer(out_csv,delimiter=',')
        
        for row in csv_reader:
           if i == 0:
               csv_writer.writerow(row)
               i += 1   # skip the first header row
               header_row = row
               for y in field_num:
                   print ('check field %s\n'%row[y])
               continue
           i =  i + 1
           found = False
           
           for column in row:
               #print(column)
               if column==key_name:
                   found = True;
                   j = j +1
                   break

           if found:
                error = False
                y = 0
                for x in field_num:
                   if increase[y] and prev_val[y] != -1 and  prev_val[y] > float(row[x]):
                       #print ('...not incrasing %d %s at row %d'%(prev_val[y],row[x],i))
                       #print (row)
                       c2 = c2+1
                       error = True 
                   if max_val[y] and float(row[x]) > max_val[y]:
                       #print ('...greater than outliner data at row %d'%i)
                       #print (row[x])
                       c3 = c3+1
                       error = True 
                   if min_val[y] and float(row[x]) <= min_val[y]:
                       #print ('...less than  outliner data at row %d'%i)
                       c1 = c1+1
                       #print (row)
                       error = True 
                   if error:
                       break
                   y = y + 1
                
                if not error:
                   csv_writer.writerow(row)  
                   for cnt, x in enumerate(field_num): 
                       prev_val[cnt] = max(prev_val[cnt],float(row[x]))
                   
                   k = k +1
                
        print('Processed %d  lines  cleaned line %d (%d, %d, %d)'%(i,k,c1,c2,c3))
# Out:
# check field Consumed_active_energy_kW
#
# check field Consumed_apparent_energy_kVAh
#
# Processed 393108  lines  cleaned line 95494 (0, 2328, 246)

# %%
import sys
import os
import csv

csv_file = '../power_test.csv'
key_name  = 'UDB2_ULC_6'
outfile ='./powertest_ULC6.out.csv'

i = 0
j = 0
prev_val = -1 
k = 0 
   
max_val = [30000,23000]

min_val = [0,0]
field_num = [49,57]#,48,57] #57 is apparent 
increase = [True,True]

prev_val = [-1 ] * len(field_num)
c1 = 0
c2 = 0
c3 = 0
with open(csv_file) as csv_file, open(outfile,'w') as out_csv:
        csv_reader = csv.reader(csv_file, delimiter=',')
        csv_writer = csv.writer(out_csv,delimiter=',')
        
        for row in csv_reader:
           if i == 0:
               csv_writer.writerow(row)
               i += 1   # skip the first header row
               header_row = row
               for y in field_num:
                   print ('check field %s\n'%row[y])
               continue
           i =  i + 1
           found = False
           
           for column in row:
               #print(column)
               if column==key_name:
                   found = True;
                   j = j +1
                   break

           if found:
                error = False
                y = 0
                for x in field_num:
                   if increase[y] and prev_val[y] != -1 and  prev_val[y] > float(row[x]):
                       #print ('...not incrasing %d %s at row %d'%(prev_val[y],row[x],i))
                       #print (row)
                       c2 = c2+1
                       error = True 
                   if max_val[y] and float(row[x]) > max_val[y]:
                       #print ('...greater than outliner data at row %d'%i)
                       #print (row[x])
                       c3 = c3+1
                       error = True 
                   if min_val[y] and float(row[x]) <= min_val[y]:
                       #print ('...less than  outliner data at row %d'%i)
                       c1 = c1+1
                       #print (row)
                       error = True 
                   if error:
                       break
                   y = y + 1
                
                if not error:
                   csv_writer.writerow(row)  
                   for cnt, x in enumerate(field_num): 
                       prev_val[cnt] = max(prev_val[cnt],float(row[x]))
                   
                   k = k +1
                
        print('Processed %d  lines  cleaned line %d (%d, %d, %d)'%(i,k,c1,c2,c3))
# Out:
# check field Consumed_active_energy_kW
#
# check field Consumed_apparent_energy_kVAh
#
# Processed 393108  lines  cleaned line 95993 (0, 2276, 54)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_active_energy_kW']
 



data1 = pd.read_csv('powertest_ULC5.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data2 = pd.read_csv('powertest_ULC6.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

target1 = data1['Consumed_active_energy_kW']
target2 = data2['Consumed_active_energy_kW']
data1= data1.reset_index()
data2= data2.reset_index()
ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[2],label=['ULC5'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[3],label=['ULC6']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed active energy kW")
plt.ylim(0,13000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.title('After dropped error values ')
plt.savefig('ULC5_ULC6_power_out_drop.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

x_col = 'Timestamp'
cols = ['Consumed_apparent_energy_kVAh']
 



data1 = pd.read_csv('powertest_ULC5.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data2 = pd.read_csv('powertest_ULC6.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

 
data1= data1.reset_index()
data2= data2.reset_index()
ax1=data1.plot(x=x_col,y=cols,marker='o',ls='None',color=colors[2],label=['ULC5'])
ax2=data2.plot(x=x_col,y=cols,ax=ax1,marker='x',ls='None',color=colors[3],label=['ULC6']) # ,label="CRAC3",ls='None',marker='x')
plt.ylabel("Consumed_apparent_energy_kVAh")
plt.ylim(0,13000)
plt.grid("on")
plt.xlabel("Date")
plt.legend()
plt.title('After dropped error values ')
plt.savefig('ULC5_ULC6_apparent_power_out_drop.csv'+'.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
data = pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
data1 = pd.read_csv('powertest_CRAC4.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)



corr = data.corr().abs()
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='rainbow', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()
outfile= 'CRAC3-pearson-fig.png'
plt.savefig(outfile)
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_51615/959335549.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
corr = data.corr(method='spearman')
corra = corr.abs()
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()
outfile=  'CRAC3-spearman-fig.png'
plt.savefig(outfile)

# %%
corr = data.corr(method='kendall')
corra = corr.abs()
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()
outfile= 'CRAC3-kendal-fig.png'
plt.savefig(outfile)
# Out:
# /Users/chantana/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:4812: RuntimeWarning: overflow encountered in long_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))

# %%
# plot correlated values
plt.rcParams['figure.figsize'] = [16, 6]

fig, ax = plt.subplots(nrows=1, ncols=3)

ax=ax.flatten()

cols = ['Consumed_apparent_energy_kVAh', 'Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']
colors=['#415952', '#f35134', '#243AB5', '#243AB5']
j=0

for i in ax:
    if j==0:
        i.set_ylabel('Consumed_active_energy_kW')
    i.scatter(data[cols[j]], data['Consumed_active_energy_kW'],  alpha=0.5, color=colors[j])
    i.set_xlabel(cols[j])
    i.set_title('Pearson: %s'%data.corr().loc[cols[j]]['Consumed_active_energy_kW'].round(2)+' Spearman: %s'%data.corr(method='spearman').loc[cols[j]]['Consumed_active_energy_kW'].round(2))
    j+=1
    
outfile= 'CRAC3-corr.png'
plt.savefig(outfile)
plt.show()

# %%
#feature selections

from sklearn import linear_model
def getTopKCorr(data,k):
    corr = data.corr().abs()
    #del data['Consumed_active_energy_kW']
    
    corr_ener = corr['Consumed_active_energy_kW']
    del corr_ener['Consumed_active_energy_kW']
    #print corr_ener.values
    #print corr_ener
    idx = (-corr_ener.values).argsort()[:k]
    print (corr_ener[idx])
    return corr_ener[idx].index

# %%
del  data['dev_name']
 
print (data.columns)

#print top 20 features for consumed energy kW
features = getTopKCorr(data,20)
print (features)
# Out:
# Index(['Threephase_Power_Factor', 'Consumed_apparent_energy_VAh', 'L2_Current',
#        'L1_Active_Power', 'Consumed_capacitive_reactive_energy_kvarhC',
#        'L2_voltage__THD', 'L1_voltage__THD', 'L3_voltage__THD',
#        'L1_Apparent_Power', 'L2L3_Voltage', 'L3_Capacitive_Power',
#        'L2_Apparent_Power', 'L1_Frequency', 'Maximum_demand_I_AVG',
#        'L1_Phase_voltage', 'Capacitive_Threephase_Powe', 'L2_Power_Factor',
#        'L3_Current', 'L2_current__THD', 'Maximum_demand_kW_III',
#        'L2_Inductive_Power', 'L2_Capacitive_Power', 'L1_Power_Factor',
#        'Consumed_inductive_reactive_energy_varhL',
#        'Consumed_inductive_reactive_energy_kvarhL', 'L3_Apparent_Power',
#        'L1_current__THD', 'L1_Current', 'L2_Active_Power', 'Cos_L1',
#        'Consumed_active_energy_W', 'Apparent_threephase_power',
#        'Maximum_demand_I_L1', 'Maximum_demand_I_L2', 'L2_Phase_voltage',
#        'L1_Inductive_Power', 'L3Power_Factor', 'Maximum_demand_kVA_III',
# ...

# %%
#select columns with features

data2 = data.iloc[:, [j for j, c in enumerate(data.columns) if c in features ]]

# %%
data2.head
# Out:
# <bound method NDFrame.head of                      Consumed_capacitive_reactive_energy_kvarhC  \
# Timestamp
# 2018-05-16 14:41:16                                         5.0
# 2018-05-16 14:41:46                                         5.0
# 2018-05-16 14:42:16                                         5.0
# 2018-05-16 14:42:46                                         5.0
# 2018-05-16 14:43:16                                         5.0
# ...                                                         ...
# 2018-07-10 10:18:00                                        23.0
# 2018-07-10 10:18:46                                        23.0
# 2018-07-10 10:19:32                                        23.0
# 2018-07-10 10:20:17                                        23.0
# 2018-07-10 10:21:03                                        23.0
#
#                      L2_voltage__THD  Capacitive_Threephase_Powe  \
# Timestamp
# 2018-05-16 14:41:16             0.12                         0.0
# ...

# %%
target = data['Consumed_active_energy_kW']
lm = linear_model.LinearRegression()
model = lm.fit(data2,target)

predictions = lm.predict(data2)

# %%
fig = plt.figure(figsize=(14,12))

plt.grid("on")
plt.xlabel("data point")
plt.ylabel("Consumed active energy")
plt.title(" Test RMSE %f"%(lm.score(data2,target)))
plt.plot(target.values,label="data")
plt.plot(predictions, color='red',linestyle='--',label="prediction")
plt.legend(loc='upper center',  shadow=True, ncol=2)

plt.show()

plt.savefig('CRAC3-predict.png')

# %%
#with no max limit check

import sys
import os
import csv

csv_file = '../power_test.csv'
key_name  = 'ADB1_CRAC3'
i = 0
j = 0
 
 
outfile ='powertest_CRAC3_nofilter.out.csv'
with open(csv_file) as csv_file, open(outfile,'w') as out_csv:
        csv_reader = csv.reader(csv_file, delimiter=',')
        csv_writer = csv.writer(out_csv,delimiter=',')
        
        for row in csv_reader:
           if i == 0:
               csv_writer.writerow(row)
               i += 1   # skip the first header row
               header_row = row
               for y in field_num:
                   print ('check field %s\n'%row[y])
               continue
           i =  i + 1
           found = False
           
           for column in row:
               #print(column)
               if column==key_name:
                   found = True;
                   j = j +1
                   break

           if found:
                csv_writer.writerow(row)  
                
                 
                
        print('Processed %d  lines found %d line '%(i,j))
# Out:
# check field Consumed_active_energy_kW
#
# check field Consumed_apparent_energy_kVAh
#
# Processed 393108  lines found 98352 line

# %%
data = pd.read_csv('powertest_CRAC3_nofilter.out.csv',index_col=0)
target = data['Consumed_active_energy_kW']
fig = plt.figure(figsize=(14,12))
plt.ylim(0,25000)
plt.grid("on")
plt.xlabel("data point")
plt.ylabel("Consumed active energy")
plt.plot(target.values,label="data")
plt.show()

# %%
 
del data['Consumed_active_energy_kW']
data2 = data.iloc[:, [j for j, c in enumerate(data.columns) if c in features ]]
lm = linear_model.LinearRegression()
model = lm.fit(data2,target)

predictions = lm.predict(data2)
fig = plt.figure(figsize=(14,12))

plt.grid("on")
plt.xlabel("data point")
plt.ylabel("Consumed active energy")
plt.ylim(0,25000)
plt.title(" Test RMSE %f"%(lm.score(data2,target)))
plt.plot(target.values,label="data")
plt.plot(predictions, color='red',linestyle='--',label="prediction")
plt.legend(loc='upper center',  shadow=True, ncol=2)

plt.show()

plt.savefig('predict_no.png')
