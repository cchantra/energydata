# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

# %%
colors = ["#9b59b6", "#e74c3c", "#34495e", "#2ecc71",'#415952', '#f35134', '#243AB5', '#243AB5', '#243AB5']
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams.update({'font.size': 16})

# %%
def time_parser(x):
    return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
import pandas as pd
data = pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
target = data['Consumed_active_energy_kW']
fig = plt.figure(figsize=(12,6))
plt.grid("on")
plt.xlabel("data point")
plt.ylabel("Consumed active energy")
plt.plot(data.index.values,target.values,label="CRAC3")
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_50894/3269736564.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
#perform data cleaning fill missing value
def resample_to_min(series,field_num):
    resample = series.resample('1T')
    minutes_data = resample.mean()
    print(minutes_data)
    minutes_data.plot()
    pyplot.show()
    return minutes_data

def fill_missing_value(df,method):
   #df = df.dropna()
   df.index = DatetimeIndex(df.index)
   df = df.interpolate(method=method, axis=0).ffill().bfill()
   print (df)
   df.plot()
   pyplot.show()
   return df

# %%
import pandas as pd

def time_parser(x):
    return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')



file_name = 'powertest_CRAC3.out.csv'
series =    pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)
del series['dev_name']
print(series.head())
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_50894/184499453.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
#                      Threephase_Power_Factor  Consumed_apparent_energy_VAh  \
# Timestamp
# 2018-05-16 14:41:16                     1.00                         756.0
# 2018-05-16 14:41:46                     1.00                         757.0
# 2018-05-16 14:42:16                     1.00                         759.0
# 2018-05-16 14:42:46                     1.00                         760.0
# 2018-05-16 14:43:16                     0.66                         762.0
#
#                      L2_Current  L1_Active_Power  \
# Timestamp
# 2018-05-16 14:41:16         0.0             0.16
# 2018-05-16 14:41:46         0.0             0.16
# 2018-05-16 14:42:16         0.0             0.16
# ...

# %%
series =    pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

del series['dev_name']
 
cols = ['Consumed_active_energy_kW','Consumed_apparent_energy_kVAh','Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']

series_new = series.filter(cols,axis=1)
 
series_new = series_new.resample('1min').mean().interpolate()
#resampled = pd.resample(tmp, '50min', 'ffill')



series_new.head
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_50894/184499453.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# <bound method NDFrame.head of                      Consumed_active_energy_kW  Consumed_apparent_energy_kVAh  \
# Timestamp
# 2018-05-16 14:41:00                     5180.0                         5413.0
# 2018-05-16 14:42:00                     5180.0                         5413.0
# 2018-05-16 14:43:00                     5180.0                         5413.0
# 2018-05-16 14:44:00                     5180.0                         5413.0
# 2018-05-16 14:45:00                     5180.0                         5413.0
# ...                                        ...                            ...
# 2018-07-10 10:17:00                    21275.0                        22123.0
# ...

# %%
len(series.columns.values)
# Out:
# 56

# %%
import pandas as pd

def time_parser(x):
    return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')


series =    pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

del series['dev_name']
 
cols = ['Consumed_active_energy_kW','Consumed_apparent_energy_kVAh','Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']

series_new = series.filter(cols,axis=1)

series_new0 = series_new.resample('30S').mean().interpolate()

series_new1 = series_new.resample('1min').mean().interpolate()
series_new2  = series_new.resample( '1min').bfill().interpolate()
series_new3 = series_new.resample('1min').mean()


print  (series_new.head)
print  (series_new0.head)
print  (series_new1.head)

print (series_new2.head)
print (series_new3.head)
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/1366980723.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# <bound method NDFrame.head of                      Consumed_active_energy_kW  Consumed_apparent_energy_kVAh  \
# Timestamp
# 2018-05-16 14:41:16                     5180.0                         5413.0
# 2018-05-16 14:41:46                     5180.0                         5413.0
# 2018-05-16 14:42:16                     5180.0                         5413.0
# 2018-05-16 14:42:46                     5180.0                         5413.0
# 2018-05-16 14:43:16                     5180.0                         5413.0
# ...                                        ...                            ...
# 2018-07-10 10:18:00                    21275.0                        22124.0
# ...

# %%
series.columns.values
# Out:
# array(['Threephase_Power_Factor', 'Consumed_apparent_energy_VAh',
#        'L2_Current', 'L1_Active_Power',
#        'Consumed_capacitive_reactive_energy_kvarhC', 'L2_voltage__THD',
#        'L1_voltage__THD', 'L3_voltage__THD', 'L1_Apparent_Power',
#        'L2L3_Voltage', 'L3_Capacitive_Power', 'L2_Apparent_Power',
#        'L1_Frequency', 'Maximum_demand_I_AVG', 'L1_Phase_voltage',
#        'Capacitive_Threephase_Powe', 'L2_Power_Factor', 'L3_Current',
#        'L2_current__THD', 'Maximum_demand_kW_III', 'L2_Inductive_Power',
#        'L2_Capacitive_Power', 'L1_Power_Factor',
#        'Consumed_inductive_reactive_energy_varhL',
#        'Consumed_inductive_reactive_energy_kvarhL', 'L3_Apparent_Power',
#        'L1_current__THD', 'L1_Current', 'L2_Active_Power', 'Cos_L1',
#        'Consumed_active_energy_W', 'Apparent_threephase_power',
#        'Maximum_demand_I_L1', 'Maximum_demand_I_L2', 'L2_Phase_voltage',
# ...

# %%
for c in series.columns.values:
    print(c)
# Out:
# Threephase_Power_Factor
# Consumed_apparent_energy_VAh
# L2_Current
# L1_Active_Power
# Consumed_capacitive_reactive_energy_kvarhC
# L2_voltage__THD
# L1_voltage__THD
# L3_voltage__THD
# L1_Apparent_Power
# L2L3_Voltage
# L3_Capacitive_Power
# L2_Apparent_Power
# L1_Frequency
# Maximum_demand_I_AVG
# L1_Phase_voltage
# Capacitive_Threephase_Powe
# L2_Power_Factor
# L3_Current
# L2_current__THD
# Maximum_demand_kW_III
# L2_Inductive_Power
# L2_Capacitive_Power
# L1_Power_Factor
# Consumed_inductive_reactive_energy_varhL
# Consumed_inductive_reactive_energy_kvarhL
# L3_Apparent_Power
# L1_current__THD
# L1_Current
# L2_Active_Power
# Cos_L1
# Consumed_active_energy_W
# Apparent_threephase_power
# Maximum_demand_I_L1
# Maximum_demand_I_L2
# L2_Phase_voltage
# L1_Inductive_Power
# L3Power_Factor
# Maximum_demand_kVA_III
# L3_current__THD
# Maximum_demand_I_L3
# L3_Phase_voltage
# L3_Inductive_Power
# L1L2_Voltage
# L3L1_Voltage
# Neutral_Current_N
# Cos_L2
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

import pandas as pd

def time_parser(x):
    return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')


series =    pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

bseries =    pd.read_csv('powertest_CRAC4.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)



del series['dev_name']
 
cols = ['Consumed_active_energy_kW','Consumed_apparent_energy_kVAh','Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']

series_new = series.filter(cols,axis=1)

series_new0 = series_new.resample('30S').mean().interpolate()

series_new1 = series_new.resample('1min').mean().interpolate()
series_new2  = series_new.resample( '1min').bfill().interpolate()
 

bseries_new = bseries.filter(cols,axis=1)

bseries_new0 = bseries_new.resample('30S').mean().interpolate()

bseries_new1 = bseries_new.resample('1min').mean().interpolate()
bseries_new2  = bseries_new.resample( '1min').bfill().interpolate()
 

target = series['Consumed_active_energy_kW']
x_val = series.index.values
target2 = series_new1['Consumed_active_energy_kW']
x_val2 = series_new1.index.values
target3 = series_new2['Consumed_active_energy_kW']
x_val3 = series_new2.index.values

target4 = series_new3['Consumed_active_energy_kW']
x_val4 = series_new3.index.values
 
fig = plt.figure(figsize=(14,12))
plt.clf()
plt.cla()
plt.grid("on")
plt.xlabel("date")
plt.ylabel("Consumed active energy")

#plt.plot(x_val,target.values,label="data",marker='o',ls='None',color=colors[0])
plt.plot(x_val2,target2.values,label="CRAC3",ls='None',marker='x',color=colors[0])
plt.plot(bseries_new1.index.values,bseries_new1['Consumed_active_energy_kW'],label="CRAC4",ls='None',marker='x',color=colors[1])
#plt.plot(x_val3,target3.values,label="data_fill",ls='None',marker='v',color=colors[2])
#plt.plot(x_val4,target4.values,label="data_sum",ls='None',marker='x',color=colors[3])
plt.title('Using mean to resampling')
plt.legend(loc='upper left')
plt.savefig('CRAC3_4_fill.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/3966507406.py:10: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
# plot correlated values
plt.rcParams['figure.figsize'] = [16, 6]
 
plt.rcParams.update({'font.size': 14})


data = series_new
fig, ax = plt.subplots(nrows=1, ncols=3)

ax=ax.flatten()

cols = ['Consumed_apparent_energy_kVAh', 'Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']
colors=['#415952', '#f35134', '#243AB5', '#243AB5']
j=0

for i in ax:
    if j==0:
        i.set_ylabel('Consumed_active_energy_kW')
    i.scatter(data[cols[j]], data['Consumed_active_energy_kW'],  alpha=0.5, color=colors[j])
    i.set_xlabel(cols[j])
    i.set_title('Pearson: %s'%data.corr().loc[cols[j]]['Consumed_active_energy_kW'].round(2)+' Spearman: %s'%data.corr(method='spearman').loc[cols[j]]['Consumed_active_energy_kW'].round(2))
    j+=1

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

 

import pandas as pd

def time_parser(x):
    return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')


series =    pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

bseries =    pd.read_csv('powertest_CRAC4.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)



del series['dev_name']
 
cols = ['Consumed_active_energy_kW','Consumed_apparent_energy_kVAh','Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']

series_new = series.filter(cols,axis=1)

series_new0 = series_new.resample('30S').mean().interpolate()

series_new1 = series_new.resample('1min').mean().interpolate()
series_new2  = series_new.resample( '1min').bfill().interpolate()
 

bseries_new = bseries.filter(cols,axis=1)

bseries_new0 = bseries_new.resample('30S').mean().interpolate()

bseries_new1 = bseries_new.resample('1min').mean().interpolate()
bseries_new2  = bseries_new.resample( '1min').bfill().interpolate()
 



target = series['Consumed_active_energy_kW']
x_val = series.index.values
target2 = series_new1['Consumed_active_energy_kW']
x_val2 = series_new1.index.values
target3 = series_new2['Consumed_active_energy_kW']
x_val3 = series_new2.index.values

target4 = series_new3['Consumed_active_energy_kW']
x_val4 = series_new3.index.values
 
fig = plt.figure(figsize=(14,12))
plt.clf()
plt.cla()
plt.grid("on")
plt.xlabel("date")
plt.ylabel("Consumed active energy")

#plt.plot(x_val,target.values,label="data",marker='o',ls='None',color=colors[0])
#plt.plot(x_val2,target2.values,label="data_mean",ls='None',marker='d',color=colors[1])
plt.plot(x_val3,target3.values,label="data_fill",ls='None',marker='v',color=colors[2])
plt.plot(bseries_new2.index.values,bseries_new2['Consumed_active_energy_kW'],label="CRAC4",ls='None',marker='x',color=colors[3])

plt.title('Using bfill to resampling')
#plt.plot(x_val4,target4.values,label="data_sum",ls='None',marker='x',color=colors[3])
plt.legend(loc='upper left')
plt.savefig('CRAC3_4_bfill.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/2581186100.py:12: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

 

import pandas as pd

def time_parser(x):
    return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')


series =    pd.read_csv('powertest_ULC5.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

bseries =    pd.read_csv('powertest_ULC6.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)



del series['dev_name']
 
cols = ['Consumed_active_energy_kW','Consumed_apparent_energy_kVAh','Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']

series_new = series.filter(cols,axis=1)

series_new0 = series_new.resample('30S').mean().interpolate()

series_new1 = series_new.resample('1min').mean().interpolate()
series_new2  = series_new.resample( '1min').bfill().interpolate()
 

bseries_new = bseries.filter(cols,axis=1)

bseries_new0 = bseries_new.resample('30S').mean().interpolate()

bseries_new1 = bseries_new.resample('1min').mean().interpolate()
bseries_new2  = bseries_new.resample( '1min').bfill().interpolate()
 



target = series['Consumed_active_energy_kW']
x_val = series.index.values
target2 = series_new1['Consumed_active_energy_kW']
x_val2 = series_new1.index.values
target3 = series_new2['Consumed_active_energy_kW']
x_val3 = series_new2.index.values

target4 = series_new3['Consumed_active_energy_kW']
x_val4 = series_new3.index.values
 
fig = plt.figure(figsize=(14,12))
plt.clf()
plt.cla()
plt.grid("on")
plt.xlabel("date")
plt.ylabel("Consumed active energy")

#plt.plot(x_val,target.values,label="data",marker='o',ls='None',color=colors[0])
#plt.plot(x_val2,target2.values,label="data_mean",ls='None',marker='d',color=colors[1])
plt.plot(x_val3,target3.values,label="data_fill",ls='None',marker='v',color=colors[2])
plt.plot(bseries_new2.index.values,bseries_new2['Consumed_active_energy_kW'],label="CRAC4",ls='None',marker='x',color=colors[3])

plt.title('Using bfill to resampling')
#plt.plot(x_val4,target4.values,label="data_sum",ls='None',marker='x',color=colors[3])
plt.legend(loc='upper left')
plt.savefig('ULC5_6_bfill.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/1897776822.py:12: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.interactive(False)

import pandas as pd

def time_parser(x):
    return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')


series =    pd.read_csv('powertest_ULC5.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

bseries =    pd.read_csv('powertest_ULC6.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)



del series['dev_name']
 
cols = ['Consumed_active_energy_kW','Consumed_apparent_energy_kVAh','Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']

series_new = series.filter(cols,axis=1)

series_new0 = series_new.resample('30S').mean().interpolate()

series_new1 = series_new.resample('1min').mean().interpolate()
series_new2  = series_new.resample( '1min').bfill().interpolate()
 

bseries_new = bseries.filter(cols,axis=1)

bseries_new0 = bseries_new.resample('30S').mean().interpolate()

bseries_new1 = bseries_new.resample('1min').mean().interpolate()
bseries_new2  = bseries_new.resample( '1min').bfill().interpolate()
 

target = series['Consumed_active_energy_kW']
x_val = series.index.values
target2 = series_new1['Consumed_active_energy_kW']
x_val2 = series_new1.index.values
target3 = series_new2['Consumed_active_energy_kW']
x_val3 = series_new2.index.values

target4 = series_new3['Consumed_active_energy_kW']
x_val4 = series_new3.index.values
 
fig = plt.figure(figsize=(14,12))
plt.clf()
plt.cla()
plt.grid("on")
plt.xlabel("date")
plt.ylabel("Consumed active energy")

#plt.plot(x_val,target.values,label="data",marker='o',ls='None',color=colors[0])
plt.plot(x_val2,target2.values,label="ULC5",ls='None',marker='x',color=colors[0])
plt.plot(bseries_new1.index.values,bseries_new1['Consumed_active_energy_kW'],label="ULC6",ls='None',marker='x',color=colors[1])
#plt.plot(x_val3,target3.values,label="data_fill",ls='None',marker='v',color=colors[2])
#plt.plot(x_val4,target4.values,label="data_sum",ls='None',marker='x',color=colors[3])
plt.title('Using mean to resampling')
plt.legend(loc='upper left')
plt.savefig('ULC5_6_fill.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/524992631.py:10: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')

# %%
from sklearn import linear_model

series =    pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

bseries =    pd.read_csv('powertest_CRAC4.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)



del series['dev_name']
 

#feature selections


def getTopKCorr(data,k):
    corr = data.corr().abs()
    #del data['Consumed_active_energy_kW']
    
    corr_ener = corr['Consumed_active_energy_kW']
    del corr_ener['Consumed_active_energy_kW']
    #print corr_ener.values
    #print corr_ener
    idx = (-corr_ener.values).argsort()[:k]
    print (corr_ener[idx])
    return corr_ener[idx].index


data = series
features = getTopKCorr(data,20)
 
print (features)

cols = list(features.values)[:2]
cols.append('Consumed_active_energy_kW')
print(cols)
#cols = ['Consumed_active_energy_kW','Consumed_apparent_energy_kVAh','Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']


 



series_new = series.filter(cols,axis=1)

series_new0 = series_new.resample('30S').mean().interpolate()

series_new1 = series_new.resample('1min').mean().interpolate()
series_new2  = series_new.resample( '1min').bfill().interpolate()
 

bseries_new = bseries.filter(cols,axis=1)

bseries_new0 = bseries_new.resample('30S').mean().interpolate()

bseries_new1 = bseries_new.resample('1min').mean().interpolate()
bseries_new2  = bseries_new.resample( '1min').bfill().interpolate()
 

target = series['Consumed_active_energy_kW']
x_val = series.index.values
target2 = series_new1['Consumed_active_energy_kW']
x_val2 = series_new1.index.values
target3 = series_new2['Consumed_active_energy_kW']
x_val3 = series_new2.index.values

target4 = series_new3['Consumed_active_energy_kW']
x_val4 = series_new3.index.values

print(series_new1.head())
 
target = series_new1['Consumed_active_energy_kW']
data2 = series_new1
del data2['Consumed_active_energy_kW']
lm = linear_model.LinearRegression()
model = lm.fit(data2,target)

predictions = lm.predict(data2)


fig = plt.figure(figsize=(14,12))

plt.grid("on")
plt.xlabel("date")
plt.ylabel("Consumed active energy")
plt.title(" CRAC3-Test RMSE %f"%(lm.score(data2,target)))
plt.plot(series_new1.index.values,target.values,label="data")
plt.plot(series_new1.index.values,predictions, color='red',linestyle= 'None' , marker = 'x',label="prediction")
plt.legend(loc='upper center',  shadow=True, ncol=2)
plt.savefig('CRAC3-clean-predict.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/3966507406.py:10: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Consumed_apparent_energy_kVAh                 0.999999
# Consumed_inductive_reactive_energy_kvarhL     0.996108
# Consumed_capacitive_reactive_energy_kvarhC    0.992277
# Consumed_inductive_reactive_energy_varhL      0.082657
# L2_voltage__THD                               0.076181
# Cos_L1                                        0.031298
# L2_current__THD                               0.030219
# Threephase_Cos                                0.028028
# L1_current__THD                               0.027929
# L3_Phase_voltage                              0.021868
# Capacitive_Threephase_Powe                    0.021530
# Cos_L2                                        0.020707
# ...

# %%
bseries =    pd.read_csv('powertest_CRAC4.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

bseries_new1 = bseries_new.resample('1min').mean().interpolate()

def getTopKCorr(data,k):
    corr = data.corr().abs()
    #del data['Consumed_active_energy_kW']
    
    corr_ener = corr['Consumed_active_energy_kW']
    del corr_ener['Consumed_active_energy_kW']
    #print corr_ener.values
    #print corr_ener
    idx = (-corr_ener.values).argsort()[:k]
    print (corr_ener[idx])
    return corr_ener[idx].index


data = bseries
features = getTopKCorr(data,20)
 
print (features)

cols = list(features.values)[:2]
cols.append('Consumed_active_energy_kW')

target = bseries_new1['Consumed_active_energy_kW']
data2 = bseries_new1
del data2['Consumed_active_energy_kW']
lm = linear_model.LinearRegression()
model = lm.fit(data2,target)

predictions = lm.predict(data2)


fig = plt.figure(figsize=(14,12))

plt.grid("on")
plt.xlabel("date")
plt.ylabel("Consumed active energy")
plt.title(" CRAC4-Test RMSE %f"%(lm.score(data2,target)))
plt.plot(bseries_new1.index.values,target.values,label="data")
plt.plot(bseries_new1.index.values,predictions, color='green',linestyle='None' , marker = 'x',label="prediction")
plt.legend(loc='upper center',  shadow=True, ncol=2)
plt.savefig('CRAC4-clean-predict.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/3966507406.py:10: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Consumed_apparent_energy_kVAh                 1.000000
# Consumed_inductive_reactive_energy_kvarhL     0.997644
# Consumed_capacitive_reactive_energy_kvarhC    0.943347
# Consumed_capacitive_reactive_energy_varhC     0.240359
# L2_voltage__THD                               0.080118
# L3Power_Factor                                0.048537
# Cos_L3                                        0.048164
# Consumed_inductive_reactive_energy_varhL      0.036408
# L1_Power_Factor                               0.033564
# L3_Phase_voltage                              0.021159
# L1_Frequency                                  0.017623
# Threephase_Cos                                0.016977
# ...

# %%
from sklearn import linear_model

series =    pd.read_csv('powertest_ULC5.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

bseries =    pd.read_csv('powertest_ULC6.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)



del series['dev_name']

def getTopKCorr(data,k):
    corr = data.corr().abs()
    #del data['Consumed_active_energy_kW']
    
    corr_ener = corr['Consumed_active_energy_kW']
    del corr_ener['Consumed_active_energy_kW']
    #print corr_ener.values
    #print corr_ener
    idx = (-corr_ener.values).argsort()[:k]
    print (corr_ener[idx])
    return corr_ener[idx].index


data = series
features = getTopKCorr(data,20)
 
print (features)

cols = list(features.values)[:3]
cols.append('Consumed_active_energy_kW')
 
#cols = ['Consumed_active_energy_kW','Consumed_apparent_energy_kVAh','Consumed_inductive_reactive_energy_kvarhL','Consumed_capacitive_reactive_energy_kvarhC']

series_new = series.filter(cols,axis=1)

series_new0 = series_new.resample('30S').mean().interpolate()

series_new1 = series_new.resample('1min').mean().interpolate()
series_new2  = series_new.resample( '1min').bfill().interpolate()
 

bseries_new = bseries.filter(cols,axis=1)

bseries_new0 = bseries_new.resample('30S').mean().interpolate()

bseries_new1 = bseries_new.resample('1min').mean().interpolate()
bseries_new2  = bseries_new.resample( '1min').bfill().interpolate()
 

target = series['Consumed_active_energy_kW']
x_val = series.index.values
target2 = series_new1['Consumed_active_energy_kW']
x_val2 = series_new1.index.values
target3 = series_new2['Consumed_active_energy_kW']
x_val3 = series_new2.index.values

target4 = series_new3['Consumed_active_energy_kW']
x_val4 = series_new3.index.values

 
target = series_new1['Consumed_active_energy_kW']
data2 = series_new1
del data2['Consumed_active_energy_kW']
lm = linear_model.LinearRegression()
model = lm.fit(data2,target)

predictions = lm.predict(data2)


fig = plt.figure(figsize=(14,12))

plt.grid("on")
plt.xlabel("date")
plt.ylabel("ULC5-Consumed active energy")
plt.title(" Test RMSE %f"%(lm.score(data2,target)))
plt.plot(series_new1.index.values,target.values,label="data")
plt.plot(series_new1.index.values,predictions, color='cyan',linestyle='None' , marker = 'x',label="prediction")
plt.legend(loc='upper center',  shadow=True, ncol=2)
plt.savefig('ULC5-clean-predict.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/3966507406.py:10: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Consumed_apparent_energy_kVAh                 1.000000
# Consumed_capacitive_reactive_energy_kvarhC    0.999750
# Neutral_Current_N                             0.375945
# Maximum_demand_I_L2                           0.343914
# Maximum_demand_I_L1                           0.324997
# L2_Current                                    0.303114
# L1_Current                                    0.261475
# L2_Apparent_Power                             0.244492
# L1_Active_Power                               0.240260
# Maximum_demand_I_L3                           0.238476
# L1_Apparent_Power                             0.226699
# L2_Active_Power                               0.215338
# ...

# %%
bseries =    pd.read_csv('powertest_ULC6.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

bseries_new1 = bseries_new.resample('1min').mean().interpolate()


def getTopKCorr(data,k):
    corr = data.corr().abs()
    #del data['Consumed_active_energy_kW']
    
    corr_ener = corr['Consumed_active_energy_kW']
    del corr_ener['Consumed_active_energy_kW']
    #print corr_ener.values
    #print corr_ener
    idx = (-corr_ener.values).argsort()[:k]
    print (corr_ener[idx])
    return corr_ener[idx].index


data = bseries
features = getTopKCorr(data,20)
 
print (features)

cols = list(features.values)[:1]
cols.append('Consumed_active_energy_kW')

target = bseries_new1['Consumed_active_energy_kW']
data2 = bseries_new1
del data2['Consumed_active_energy_kW']
lm = linear_model.LinearRegression()
model = lm.fit(data2,target)

predictions = lm.predict(data2)


fig = plt.figure(figsize=(14,12))

plt.grid("on")
plt.xlabel("date")
plt.ylabel("Consumed active energy")
plt.title(" ULC6-Test RMSE %f"%(lm.score(data2,target)))
plt.plot(bseries_new1.index.values,target.values,label="data")
plt.plot(bseries_new1.index.values,predictions, color='red',linestyle='None',marker='x',label="prediction")
plt.legend(loc='upper center',  shadow=True, ncol=2)
plt.savefig('ULC6-clean-predict.png')
plt.show()
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/3966507406.py:10: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Consumed_apparent_energy_kVAh                 1.000000
# Consumed_capacitive_reactive_energy_kvarhC    0.999999
# Maximum_demand_I_L3                           0.348570
# Maximum_demand_kVA_III                        0.204678
# Maximum_demand_I_AVG                          0.196472
# Maximum_demand_kW_III                         0.182168
# Maximum_demand_I_L2                           0.153298
# Maximum_demand_I_L1                           0.127473
# Neutral_Current_N                             0.105638
# L2_Current                                    0.089193
# Active_Threephase_Power                       0.088167
# L1_Current                                    0.081421
# ...

# %%
from sklearn import linear_model
def getTopKCorr(data,k):
    corr = data.corr().abs()
    #del data['Consumed_active_energy_kW']
    
    corr_ener = corr['Consumed_active_energy_kW']
    del corr_ener['Consumed_active_energy_kW']
    #print corr_ener.values
    #print corr_ener
    idx = (-corr_ener.values).argsort()[:k]
    print (corr_ener[idx])
    return corr_ener[idx].index

# %%
data = pd.read_csv('powertest_CRAC3.out.csv',index_col='Timestamp',parse_dates=True,date_parser=time_parser)

del  data['dev_name']
 
print (data.columns)

#print top 20 features for consumed energy kW
features = getTopKCorr(data,20)
print (features)

cols = list(features.values)[:5]
# Out:
# /var/folders/ty/r8ylvb8n32b96f_fmbbsk5b40000gn/T/ipykernel_53690/2581186100.py:12: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   return pd.datetime.strptime(x, '%d/%m/%Y %H:%M:%S')
# Index(['Threephase_Power_Factor', 'Consumed_apparent_energy_VAh', 'L2_Current',
#        'L1_Active_Power', 'Consumed_capacitive_reactive_energy_kvarhC',
#        'L2_voltage__THD', 'L1_voltage__THD', 'L3_voltage__THD',
#        'L1_Apparent_Power', 'L2L3_Voltage', 'L3_Capacitive_Power',
#        'L2_Apparent_Power', 'L1_Frequency', 'Maximum_demand_I_AVG',
#        'L1_Phase_voltage', 'Capacitive_Threephase_Powe', 'L2_Power_Factor',
#        'L3_Current', 'L2_current__THD', 'Maximum_demand_kW_III',
#        'L2_Inductive_Power', 'L2_Capacitive_Power', 'L1_Power_Factor',
#        'Consumed_inductive_reactive_energy_varhL',
#        'Consumed_inductive_reactive_energy_kvarhL', 'L3_Apparent_Power',
# ...
